# %%
import re
from IPython.display import display
from ipywidgets import widgets

# %%
prog = re.compile("(?:\s|^)((?:[^\s][^a-zA-Z1-9\n]+)(?:[^\s](?:[^a-zA-Z1-9\n]+|$))+)")
emojiiTable = {}
for fn in ['train_pos.txt', 'train_neg.txt','test_data.txt']:
    with open(fn) as f:
        for line in f.readlines():
            for result in prog.finditer(line):
                g1 = result.group(1).strip()
                if not g1 in emojiiTable:
                    emojiiTable[g1] = (1,line)
                else:
                    emojiiTable[g1] = (emojiiTable[g1][0] + 1,emojiiTable[g1][1])
theList =  [(v[0], v[1], k) for k, v in emojiiTable.items()]
theListSorted = sorted(theList, key=lambda t: t[0])
theListSorted[-150:]
t2 = {}
for _, sample, moji in theListSorted[-150:]:
    print('"'+moji+'" in "'+sample)
    t2[moji] = input()
    
with open('emojtable.pkl', 'wb') as f:
        pickle.dump(t2, f, pickle.HIGHEST_PROTOCOL)
# Out:
# [(88,
#   'price drop : vcp 5 vmware vsphere 5 exam question ( educ vcp 5 vmware vsphere 5 exam question 2.0 devic : ... #io\n',
#   '2.0'),
#  (89,
#   "stop perv facebook ! :p haha , joke ! nooo , , she mess ! next you'll say love glee ! god\n",
#   '! :p'),
#  (89, 'lala cuti yeah im 6 - 10:30 wooop may pop see kidda ! xxx\n', '6 -'),
#  (92,
#   "yay ! :d believ : 3 although america ... don't money xd lucki\n",
#   ': 3'),
#  (92, "thank sir > > don't trip lil mama ... keep doin ya thang !\n", '> >'),
#  (93,
#   'hey ( . skyeee_ox ) ! follow ( . iswagtumblr ) love , funni , true , epic , relat quot !\n',
#   '( .'),
#  (93,
#   'campuran bhsa nya , welcom yu rt arigato thankyou " like rt ... ( cont )\n',
#   '... ('),
#  (93,
#   '[ pleas rt ] #ss4ina trade 1 superbox b 29 april ( day 3 ) 1 superbox c 29 april ( day 3 ) mention\n',
#   '3 )'),
#  (93,
#   'mention cafe en sein : - rt fab nite cafe en sein buddi lotsa laugh crazi ...\n',
#   ': -'),
#  (95, ') u ?\n', 'u ?'),
#  (96, "welp , im doin ' . yes ; we'r huge failur #wahh . lol\n", "' ."),
#  (96,
#   'may weekend got fill . 1 - lake day birthday crazi , 2 - az boy , 3 - ny bff 4 - cali cousin ! ! ! #yesimbrag #noimnotsorri\n',
#   '4 -'),
#  (97, "much sleep need ? morn show , i'd need bed 9\n", ", i'd"),
#  (98, 'rt " guess doesn\'t give fuck ! * rais hand * "\n', '! *'),
#  (98,
#   '( women ) ... know say abt big shoe ... big uterus .. uhhh 0_o ? ? ... #somemovi\n',
#   ') ...'),
#  (99,
#   "boy : ' ' heard like bad boy ' ' ' ' girl : ' ' yeaah ' ' boy : ' ' well tri impress anyth swim without floati ' '\n",
#   ": ' '"),
#  (101,
#   'cabl go 03011 db25 femal / femal null modem cabl , beig ( 6 feet / 1.82 meter line null modem seria ...\n',
#   '( 6'),
#  (101, 'yeah ~ ) 4 , great job . * laugh *\n', '. *'),
#  (102, 'thought loud night ! : manchest #swag reesh would say xxx\n', '! :'),
#  (103, "well , that amaz honor ! , you'r cross dress , ?\n", '! ,'),
#  (104, 'made thus guy earli birthday wish ! ! )\n', '! ! )'),
#  (108, 'ask question everyday .. " your day " lol\n', '.. "'),
#  (108, 'naaah , " je vous aim " . ich habe euch lieb . right ?\n', '" .'),
#  (108,
#   "i'm stay singl need focus instead girl ! ! i'm still gonna fun #singlelif go ok\n",
#   "! ! i'm"),
#  (108, 'still boo though <3 3 - mr.gaskin\n', '3 -'),
#  (109,
#   '" #ididnttextyouback hit want someth - __ - " friend like ! ! ! ) ) )\n',
#   '- "'),
#  (109,
#   'rip ! : deconstruct reconstruct cloth dream ( paperback spend ton money h ...\n',
#   'h ...'),
#  (110, "i'v alright , hbu ? go huenem right ? :\n", '? :'),
#  (110,
#   '#1dnextalbumtitl : feel / rollercoast life . song cocept : life , #yolo , becom famous ? <3 14 #followmeplz ! <3 x15\n',
#   '? <3'),
#  (111, '.. well , sky blue today ! .\n', '! .'),
#  (112, 'ok . & yeah . tell !\n', '. &'),
#  (113, "gonna talk tomorrow ? ... hope you'll good night xoxoxo\n", '? ...'),
#  (115,
#   'gomawoo mom ^ ^ rt [ ! ! ! ] new coupl ~ sf_jyjjaejoong chukka longlast\n',
#   '^ ^'),
#  (116,
#   'tulli coffe kona blend extra-bold , 24 - count k-cup keurig brewer ( pack 2 ) offer promot today\n',
#   '2 )'),
#  (117,
#   '" ain\'t easi green " ... everyon want stop stare full size wallpap download ...\n',
#   '" ...'),
#  (117,
#   "hell yeah . ! ! ! wish could hotbox togeth that'd cool haha take coupla hit me'll u !\n",
#   'u !'),
#  (118, "74,i'm so weak ! i will never lose weight !\n", '! i'),
#  (119,
#   "insid someth found , wanna shop around . i'v jus begun fun\n",
#   ". i'v"),
#  (120,
#   "read someth , i'v realis .. know noth ;] confus text baaahaaa ! love xxx\n",
#   ", i'v"),
#  (120,
#   'ahh right haha fairdoo ! & mate sure youd rather meet , etc , it brainier man\n',
#   '! &'),
#  (120,
#   'live life quot " live life moment cos everyth els uncertain " - loui tomlinson\n',
#   '" -'),
#  (121,
#   "niall got brace , can't wait see caus he sucha wee cutey anyway aww one direct ... like . . .\n",
#   '. . .'),
#  (125,
#   'duuud don\'t tell kid thing ;d rt hahah 5 year nonstop rebel ! rt " thabzz : ...\n',
#   ': ...'),
#  (125,
#   "well isn't sweet lol tell leav u alon els someon ( ) get f * * ked\n",
#   '( )'),
#  (126, '" oh okay good . u fli depress " thank boo : - *\n', '. u'),
#  (126,
#   'lol 7eleven anti depressaint rt * buka peta * * peta ke vikarion * rt * empati * rt empti\n',
#   '* *'),
#  (127,
#   'hon , sure " hehe , nichek tu ! ur day come " lol ... " mulika mwizi " style ... ehe ? ? "\n',
#   '... "'),
#  (127, "seee got problem & don't know caus ' ...\n", "' ..."),
#  (127,
#   'take part bollywood danc class tomorrow ( thx caravan burlesqu ) . photo pleas\n',
#   ') .'),
#  (129,
#   'revis ( 6.5 -> 6.7 6.7 earthquak , offshor valparaiso , chile . apr 16 11:50 pm epicent ( 1h : 16m ago , 42km nne ...\n',
#   '( 6.5 -> 6.7 6.7'),
#  (129, 'umm duh ! told ! u need come cracow\n', '! u'),
#  (131, "ok everyon talk pbb we'r fangirl . how make chang ? )\n", '? )'),
#  (131, 'beretta yet , (\n', ', ('),
#  (131, "don't play dumb like everi girl - ___ - ( sarcasm includ )\n", '- ('),
#  (135, "what ? i'm sister homework - _ -\n", '- _ -'),
#  (137,
#   "ritz cracker ' n cheez , 0.95- ounc singl serv packag ( pack 60\n",
#   ', 0.'),
#  (141, 'noth much . ? pretti name btw .\n', '. ?'),
#  (142, 'hi , follow pleas pleas , . kiss franc x3 2032112 2\n', ', .'),
#  (143,
#   'liammm . tri crowd surf prefer may 28th concert toward section 100 row w ... yes ?\n',
#   'w ...'),
#  (148, "- . - rt reaction i'm get last tweet haitian >\n", '. -'),
#  (149, 'yesss bet move like move england - . -\n', '- . -'),
#  (150, 'tryna get facetim wit p ...\n', 'p ...'),
#  (151,
#   'economist agre higher vat r way go ( hst / gst 4 us ) , tri sell double-doubl mass !\n',
#   ') ,'),
#  (151, 'text got cori < < <\n', '< < <'),
#  (152, 'done x tweet one fav tho . alway rt see , tbh . hhahaha . x\n', '. x'),
#  (156,
#   'love nuck sinc grade 2 ( daycar gave us free ticket game ) lol muthafucka wanna jump wagon today - hop !\n',
#   '2 ('),
#  (157, '#losemynumb 2 - face fake\n', '2 -'),
#  (158,
#   "he wrink :') you'll get ladi : l one resist ador puppi zubi cool name : l\n",
#   ': l'),
#  (158, 'newpic #nsfw #sexi hot blond readi game love ( 1\n', '( 1'),
#  (159, 'naaah , " je vous aim " . ich habe euch lieb . right ?\n', ', "'),
#  (160, 'world best dad . <3\n', '. <3'),
#  (163, 'pretti good , ? xx\n', ', ?'),
#  (164,
#   'ride wave : life sound , scienc , industri ( hardcov life work renaiss man leo b ...\n',
#   'b ...'),
#  (166,
#   "babe i'm sorri moonshin better show watch .. i'm realli sorri say\n",
#   ".. i'm"),
#  (168,
#   'embassi larg genuin leather purs ( apparel embassi larg genuin leather purs . measur 141/2 " x 91/2 " x 51 ...\n',
#   '" x'),
#  (170, ': - ... well well well ... thts surpris !\n', '- ...'),
#  (172,
#   'would nice surpris ... im mood bs ! ... back regular schedul program\n',
#   '! ...'),
#  (178, 'say " hello mari franc " ( live\n', '" ('),
#  (179,
#   'ibm thinkcentr a52 8160 1gb memori ram kit ( 2x512mb ) ( a-tech brand 1gb ddr 2-533 ( pc2 - 4200 ) kit ( 2x512mb ) ...\n',
#   ') ( a-'),
#  (180, "lol chloe :') ill teach yous cook , you'll pros end !\n", ":')"),
#  (180,
#   'star brite economi boat hook ( 4-8- feet telescop pole extend 4 ( 124 cm ) 8 ( 243 cm ) special f ...\n',
#   'f ...'),
#  (181, 'wisdom sand : discours sufism ( 2 volum\n', '( 2'),
#  (181,
#   "hey , u help group ? we'r video campaign .. need view link ->\n",
#   ', u'),
#  (182,
#   "we'r excit find who go get goodi bag today ! perfect excus littl ' ' time #groovymum\n",
#   "' '"),
#  (182, 'thank love & & def get done ) plenti want frame lol\n', '& &'),
#  (193,
#   '5,whenever i fall asleep watching the tv , i always wake up with a headache\n',
#   ', i'),
#  (196, 'miss < / 3 miss ! ! ! , tana needa get togeth soon\n', '< / 3'),
#  (197,
#   '04x27 custom pictur frame / poster frame 1.5 " wide complet american mapl brown frame ( 17015 frame ...\n',
#   '1.5 "'),
#  (199, "know ! can't believ ! i'll send pic hall !\n", "! i'"),
#  (201,
#   'fresh air ? low blood sugar ( grab snack ) ? much squint [ comput / note ] ( grab break ) ?\n',
#   '] ('),
#  (201, 'bitch laugh ? hahaha love shawti : *\n', ': *'),
#  (219,
#   'everyon entitl opinion respect . , still trash jeff long die fire . good night .\n',
#   '. ,'),
#  (221,
#   "13,<user> robert de niro is not gay .. but with a name like lewy , i'd understand if you were hahahahha no . i am sherlock\n",
#   '. i'),
#  (226, 'text brother antquan . !\n', '. !'),
#  (228,
#   'artec kiwi coloreflector shampoo , 33.8- ounc bottl ( health beauti experi kiwi coloreflector , hair c ...\n',
#   'c ...'),
#  (235,
#   "ditto . safe travel , love ! rt guy ? i'm think . hope got smile least today\n",
#   "? i'm"),
#  (238, 'need book t4 beach ticket ! ! ! #excit\n', '! ! ! #'),
#  (241,
#   "film across canada ! :d especi ottawa lot fan ! - p . . i'd like audit film\n",
#   '! :d'),
#  (243,
#   'summer day : 1 . ) work 10:30- 2:30 ish .. 2 . ) home , shower , & eat ... 3 . ) go till whenev\n',
#   ', &'),
#  (245, "rt goodnight ... i'm proud , cluuue , one deserv\n", "... i'm"),
#  (254, '- - - type girl chang life\n', '- -'),
#  (261, 'im post cover " young " " turn tabl " ! ! check tonight !\n', '" "'),
#  (268,
#   'omg that shit ! .. rt " make good love , , avant .. > def babi make playlist lol "\n',
#   ', ,'),
#  (278,
#   'dell inspiron 2500 piii 850 128mb memori ram upgrad ( a-tech brand 128mb pc100 sdram so-dimm dell inspiron ...\n',
#   '( a-'),
#  (279, "saw . i'll repli bit .\n", ". i'"),
#  (283,
#   '3 word , 2 second , 1 moment : " thank god . " rt thank today , everyday !\n',
#   ', 1'),
#  (286, '~ bell yes probabl , 2\n', ', 2'),
#  (288,
#   'text " fhwj 77 1 " 70070 donat quick quid bunge jump ranger chariti foundat ! ! pleas rt ! #gersfamili x\n',
#   '1 "'),
#  (289,
#   'that exact u guy / girl miss sum 1 u could actual enjoy be-n . ... . #advicetewwhoevaneedsit . .\n',
#   '. .'),
#  (289, 'found part sing ! ! ! shoutout ? ( live\n', '? ('),
#  (290, "aahh , sorri love ... know you'll ace . )\n", '. )'),
#  (301, "dm'd get follow follow new twitter . shindig ? x\n", '? x'),
#  (312,
#   '( ) ; rt yes , yes . " chelsea , mean i\'m gonna valedictorian ? "\n',
#   '? "'),
#  (323,
#   '" avi > > > look like anim charact someth " thank big brother <3 luh yewww hoe !\n',
#   '> > >'),
#  (330, 'boy special enough first time . ahahahha . may te ) ) )\n', ') ) )'),
#  (332, 'thank , im sleep . kid ! ) game 5am ?\n', '! )'),
#  (340, 'yay ! ! #lifecomplet . tweet / facebook let know pleas\n', '! ! #'),
#  (344, '; rt taylor inspir trend topic world wide # 1\n', '# 1'),
#  (352,
#   'smirk norway killer breivik plead guilti ( reuter share friend : | | world news - top stori news , news feed n ...\n',
#   ': | |'),
#  (355,
#   '#1dnextalbumtitl : feel / rollercoast life . song cocept : life , #yolo , becom famous ? <3 14 #followmeplz ! <3 x15\n',
#   '! <3'),
#  (366, "better make wrong decis today , i'll upset #reallythough\n", ", i'"),
#  (372, "i'm week thanksss ! ? xxx\n", '! ?'),
#  (387, 'daili sentenc : " hate french teacher . " lmao <3\n', ': "'),
#  (390, 'zed ! msh aja ! ( rt lipbalm , salep kutu air ... ...\n', '! ('),
#  (405, '" put casper box ! " loov battl ! #crakkbitch\n', '! "'),
#  (416,
#   "morn . poor colton . wasn't fan would'v surviv win #idol phillip . ... shit . happi elis & holli surviv tho\n",
#   '. ...'),
#  (431, "coupl cover i'd never actual drawn octopus ... love\n", "i'd"),
#  (467, 'oh yeah still talk shxt ? ? ? hoe\n', '? ? ?'),
#  (492, 'love come outta freez classroom warm sun ( (\n', '( ('),
#  (501, 'love callin men " big poppa " phone ( ( (\n', '( ( ('),
#  (529,
#   'jersey shore 13x25 custom pictur frame / poster frame 2 " wide complet black wood frame (8 941 frame ...\n',
#   '2 "'),
#  (552, 'watch hehe ) )\n', ') )'),
#  (565, 'first twitcam ever watch boy . ( live\n', '. ('),
#  (622, '/ goofi self fuck w / tuff know wassup follow punk\n', 'w /'),
#  (650,
#   "haha ahww ) good ! i'm excit see ! know act like hang watermelon bust ? #whatupwiththat\n",
#   "! i'm"),
#  (726,
#   'make infant steeler jersey roethlisberg ? he babi daddi like alway hope , ...\n',
#   ', ...'),
#  (813,
#   "enough #howgoodcouldihavebeenif i'm start new hastag ... #howgreatimgonnabebecaus\n",
#   '... #'),
#  (846,
#   "ok , leto - i'v w / u 18yr ! i'v bought movi / cd / vyrt ass ! think i'v earn call ? u want blood ? !\n",
#   "i'v"),
#  (884, 'keep lay around ass ? !\n', '? !'),
#  (905, "happi 4.20 real . i'm spark name .\n", ". i'm"),
#  (929, '" " long day , bed . " night morn " morn sharon\n', '. "'),
#  (1049,
#   'friday payday & 4/20 ? ? hell yeah #reasons2dothebirdmanhandrub\n',
#   '? ?'),
#  (1102,
#   'feel better , feel bad , feel better , feel bad , work ... <\n',
#   '... <'),
#  (1185, "whatev time , i'm bother .\n", ", i'm"),
#  (1935, 'ah glad hear . must someth soon ! x\n', '! x'),
#  (2221,
#   'photo : chillin boy ! may know ? phinea ferm ) ( taken instagram )\n',
#   ') ('),
#  (4696, 'visit brother tmr bestest birthday gift eveerrr ! ! !\n', '! ! !'),
#  (6106, "got mid-term i'm impress ! ! #happi\n", "i'm"),
#  (6272,
#   'grate today dream fulfil ! ! heart full - first 3 complet track arriv back new york ! #yeslord !\n',
#   '! !'),
#  (33630,
#   "thank sir > > don't trip lil mama ... keep doin ya thang !\n",
#   '...')]

# %%
theListSorted = sorted(theList, key=lambda t: t[0][0])

# %%
theListSorted[-150:]
# Out:
# [([88,
#    'price drop : vcp 5 vmware vsphere 5 exam question ( educ vcp 5 vmware vsphere 5 exam question 2.0 devic : ... #io\n'],
#   '2.0'),
#  ([89,
#    "stop perv facebook ! :p haha , joke ! nooo , , she mess ! next you'll say love glee ! god\n"],
#   '! :p'),
#  ([89, 'lala cuti yeah im 6 - 10:30 wooop may pop see kidda ! xxx\n'], '6 -'),
#  ([92, "yay ! :d believ : 3 although america ... don't money xd lucki\n"],
#   ': 3'),
#  ([92, "thank sir > > don't trip lil mama ... keep doin ya thang !\n"], '> >'),
#  ([93,
#    'hey ( . skyeee_ox ) ! follow ( . iswagtumblr ) love , funni , true , epic , relat quot !\n'],
#   '( .'),
#  ([93,
#    'campuran bhsa nya , welcom yu rt arigato thankyou " like rt ... ( cont )\n'],
#   '... ('),
#  ([93,
#    '[ pleas rt ] #ss4ina trade 1 superbox b 29 april ( day 3 ) 1 superbox c 29 april ( day 3 ) mention\n'],
#   '3 )'),
#  ([93,
#    'mention cafe en sein : - rt fab nite cafe en sein buddi lotsa laugh crazi ...\n'],
#   ': -'),
#  ([95, ') u ?\n'], 'u ?'),
#  ([96, "welp , im doin ' . yes ; we'r huge failur #wahh . lol\n"], "' ."),
#  ([96,
#    'may weekend got fill . 1 - lake day birthday crazi , 2 - az boy , 3 - ny bff 4 - cali cousin ! ! ! #yesimbrag #noimnotsorri\n'],
#   '4 -'),
#  ([97, "much sleep need ? morn show , i'd need bed 9\n"], ", i'd"),
#  ([98, 'rt " guess doesn\'t give fuck ! * rais hand * "\n'], '! *'),
#  ([98,
#    '( women ) ... know say abt big shoe ... big uterus .. uhhh 0_o ? ? ... #somemovi\n'],
#   ') ...'),
#  ([99,
#    "boy : ' ' heard like bad boy ' ' ' ' girl : ' ' yeaah ' ' boy : ' ' well tri impress anyth swim without floati ' '\n"],
#   ": ' '"),
#  ([101,
#    'cabl go 03011 db25 femal / femal null modem cabl , beig ( 6 feet / 1.82 meter line null modem seria ...\n'],
#   '( 6'),
#  ([101, 'yeah ~ ) 4 , great job . * laugh *\n'], '. *'),
#  ([102, 'thought loud night ! : manchest #swag reesh would say xxx\n'], '! :'),
#  ([103, "well , that amaz honor ! , you'r cross dress , ?\n"], '! ,'),
#  ([104, 'made thus guy earli birthday wish ! ! )\n'], '! ! )'),
#  ([108, 'ask question everyday .. " your day " lol\n'], '.. "'),
#  ([108, 'naaah , " je vous aim " . ich habe euch lieb . right ?\n'], '" .'),
#  ([108,
#    "i'm stay singl need focus instead girl ! ! i'm still gonna fun #singlelif go ok\n"],
#   "! ! i'm"),
#  ([108, 'still boo though <3 3 - mr.gaskin\n'], '3 -'),
#  ([109,
#    '" #ididnttextyouback hit want someth - __ - " friend like ! ! ! ) ) )\n'],
#   '- "'),
#  ([109,
#    'rip ! : deconstruct reconstruct cloth dream ( paperback spend ton money h ...\n'],
#   'h ...'),
#  ([110, "i'v alright , hbu ? go huenem right ? :\n"], '? :'),
#  ([110,
#    '#1dnextalbumtitl : feel / rollercoast life . song cocept : life , #yolo , becom famous ? <3 14 #followmeplz ! <3 x15\n'],
#   '? <3'),
#  ([111, '.. well , sky blue today ! .\n'], '! .'),
#  ([112, 'ok . & yeah . tell !\n'], '. &'),
#  ([113, "gonna talk tomorrow ? ... hope you'll good night xoxoxo\n"], '? ...'),
#  ([115,
#    'gomawoo mom ^ ^ rt [ ! ! ! ] new coupl ~ sf_jyjjaejoong chukka longlast\n'],
#   '^ ^'),
#  ([116,
#    'tulli coffe kona blend extra-bold , 24 - count k-cup keurig brewer ( pack 2 ) offer promot today\n'],
#   '2 )'),
#  ([117,
#    '" ain\'t easi green " ... everyon want stop stare full size wallpap download ...\n'],
#   '" ...'),
#  ([117,
#    "hell yeah . ! ! ! wish could hotbox togeth that'd cool haha take coupla hit me'll u !\n"],
#   'u !'),
#  ([118, "74,i'm so weak ! i will never lose weight !\n"], '! i'),
#  ([119, "insid someth found , wanna shop around . i'v jus begun fun\n"],
#   ". i'v"),
#  ([120,
#    "read someth , i'v realis .. know noth ;] confus text baaahaaa ! love xxx\n"],
#   ", i'v"),
#  ([120,
#    'ahh right haha fairdoo ! & mate sure youd rather meet , etc , it brainier man\n'],
#   '! &'),
#  ([120,
#    'live life quot " live life moment cos everyth els uncertain " - loui tomlinson\n'],
#   '" -'),
#  ([121,
#    "niall got brace , can't wait see caus he sucha wee cutey anyway aww one direct ... like . . .\n"],
#   '. . .'),
#  ([125,
#    'duuud don\'t tell kid thing ;d rt hahah 5 year nonstop rebel ! rt " thabzz : ...\n'],
#   ': ...'),
#  ([125,
#    "well isn't sweet lol tell leav u alon els someon ( ) get f * * ked\n"],
#   '( )'),
#  ([126, '" oh okay good . u fli depress " thank boo : - *\n'], '. u'),
#  ([126,
#    'lol 7eleven anti depressaint rt * buka peta * * peta ke vikarion * rt * empati * rt empti\n'],
#   '* *'),
#  ([127,
#    'hon , sure " hehe , nichek tu ! ur day come " lol ... " mulika mwizi " style ... ehe ? ? "\n'],
#   '... "'),
#  ([127, "seee got problem & don't know caus ' ...\n"], "' ..."),
#  ([127,
#    'take part bollywood danc class tomorrow ( thx caravan burlesqu ) . photo pleas\n'],
#   ') .'),
#  ([129,
#    'revis ( 6.5 -> 6.7 6.7 earthquak , offshor valparaiso , chile . apr 16 11:50 pm epicent ( 1h : 16m ago , 42km nne ...\n'],
#   '( 6.5 -> 6.7 6.7'),
#  ([129, 'umm duh ! told ! u need come cracow\n'], '! u'),
#  ([131, "ok everyon talk pbb we'r fangirl . how make chang ? )\n"], '? )'),
#  ([131, 'beretta yet , (\n'], ', ('),
#  ([131, "don't play dumb like everi girl - ___ - ( sarcasm includ )\n"],
#   '- ('),
#  ([135, "what ? i'm sister homework - _ -\n"], '- _ -'),
#  ([137, "ritz cracker ' n cheez , 0.95- ounc singl serv packag ( pack 60\n"],
#   ', 0.'),
#  ([141, 'noth much . ? pretti name btw .\n'], '. ?'),
#  ([142, 'hi , follow pleas pleas , . kiss franc x3 2032112 2\n'], ', .'),
#  ([143,
#    'liammm . tri crowd surf prefer may 28th concert toward section 100 row w ... yes ?\n'],
#   'w ...'),
#  ([148, "- . - rt reaction i'm get last tweet haitian >\n"], '. -'),
#  ([149, 'yesss bet move like move england - . -\n'], '- . -'),
#  ([150, 'tryna get facetim wit p ...\n'], 'p ...'),
#  ([151,
#    'economist agre higher vat r way go ( hst / gst 4 us ) , tri sell double-doubl mass !\n'],
#   ') ,'),
#  ([151, 'text got cori < < <\n'], '< < <'),
#  ([152, 'done x tweet one fav tho . alway rt see , tbh . hhahaha . x\n'],
#   '. x'),
#  ([156,
#    'love nuck sinc grade 2 ( daycar gave us free ticket game ) lol muthafucka wanna jump wagon today - hop !\n'],
#   '2 ('),
#  ([157, '#losemynumb 2 - face fake\n'], '2 -'),
#  ([158,
#    "he wrink :') you'll get ladi : l one resist ador puppi zubi cool name : l\n"],
#   ': l'),
#  ([158, 'newpic #nsfw #sexi hot blond readi game love ( 1\n'], '( 1'),
#  ([159, 'naaah , " je vous aim " . ich habe euch lieb . right ?\n'], ', "'),
#  ([160, 'world best dad . <3\n'], '. <3'),
#  ([163, 'pretti good , ? xx\n'], ', ?'),
#  ([164,
#    'ride wave : life sound , scienc , industri ( hardcov life work renaiss man leo b ...\n'],
#   'b ...'),
#  ([166, "babe i'm sorri moonshin better show watch .. i'm realli sorri say\n"],
#   ".. i'm"),
#  ([168,
#    'embassi larg genuin leather purs ( apparel embassi larg genuin leather purs . measur 141/2 " x 91/2 " x 51 ...\n'],
#   '" x'),
#  ([170, ': - ... well well well ... thts surpris !\n'], '- ...'),
#  ([172,
#    'would nice surpris ... im mood bs ! ... back regular schedul program\n'],
#   '! ...'),
#  ([178, 'say " hello mari franc " ( live\n'], '" ('),
#  ([179,
#    'ibm thinkcentr a52 8160 1gb memori ram kit ( 2x512mb ) ( a-tech brand 1gb ddr 2-533 ( pc2 - 4200 ) kit ( 2x512mb ) ...\n'],
#   ') ( a-'),
#  ([180, "lol chloe :') ill teach yous cook , you'll pros end !\n"], ":')"),
#  ([180,
#    'star brite economi boat hook ( 4-8- feet telescop pole extend 4 ( 124 cm ) 8 ( 243 cm ) special f ...\n'],
#   'f ...'),
#  ([181, 'wisdom sand : discours sufism ( 2 volum\n'], '( 2'),
#  ([181, "hey , u help group ? we'r video campaign .. need view link ->\n"],
#   ', u'),
#  ([182,
#    "we'r excit find who go get goodi bag today ! perfect excus littl ' ' time #groovymum\n"],
#   "' '"),
#  ([182, 'thank love & & def get done ) plenti want frame lol\n'], '& &'),
#  ([193,
#    '5,whenever i fall asleep watching the tv , i always wake up with a headache\n'],
#   ', i'),
#  ([196, 'miss < / 3 miss ! ! ! , tana needa get togeth soon\n'], '< / 3'),
#  ([197,
#    '04x27 custom pictur frame / poster frame 1.5 " wide complet american mapl brown frame ( 17015 frame ...\n'],
#   '1.5 "'),
#  ([199, "know ! can't believ ! i'll send pic hall !\n"], "! i'"),
#  ([201,
#    'fresh air ? low blood sugar ( grab snack ) ? much squint [ comput / note ] ( grab break ) ?\n'],
#   '] ('),
#  ([201, 'bitch laugh ? hahaha love shawti : *\n'], ': *'),
#  ([219,
#    'everyon entitl opinion respect . , still trash jeff long die fire . good night .\n'],
#   '. ,'),
#  ([221,
#    "13,<user> robert de niro is not gay .. but with a name like lewy , i'd understand if you were hahahahha no . i am sherlock\n"],
#   '. i'),
#  ([226, 'text brother antquan . !\n'], '. !'),
#  ([228,
#    'artec kiwi coloreflector shampoo , 33.8- ounc bottl ( health beauti experi kiwi coloreflector , hair c ...\n'],
#   'c ...'),
#  ([235,
#    "ditto . safe travel , love ! rt guy ? i'm think . hope got smile least today\n"],
#   "? i'm"),
#  ([238, 'need book t4 beach ticket ! ! ! #excit\n'], '! ! ! #'),
#  ([241,
#    "film across canada ! :d especi ottawa lot fan ! - p . . i'd like audit film\n"],
#   '! :d'),
#  ([243,
#    'summer day : 1 . ) work 10:30- 2:30 ish .. 2 . ) home , shower , & eat ... 3 . ) go till whenev\n'],
#   ', &'),
#  ([245, "rt goodnight ... i'm proud , cluuue , one deserv\n"], "... i'm"),
#  ([254, '- - - type girl chang life\n'], '- -'),
#  ([261, 'im post cover " young " " turn tabl " ! ! check tonight !\n'], '" "'),
#  ([268,
#    'omg that shit ! .. rt " make good love , , avant .. > def babi make playlist lol "\n'],
#   ', ,'),
#  ([278,
#    'dell inspiron 2500 piii 850 128mb memori ram upgrad ( a-tech brand 128mb pc100 sdram so-dimm dell inspiron ...\n'],
#   '( a-'),
#  ([279, "saw . i'll repli bit .\n"], ". i'"),
#  ([283,
#    '3 word , 2 second , 1 moment : " thank god . " rt thank today , everyday !\n'],
#   ', 1'),
#  ([286, '~ bell yes probabl , 2\n'], ', 2'),
#  ([288,
#    'text " fhwj 77 1 " 70070 donat quick quid bunge jump ranger chariti foundat ! ! pleas rt ! #gersfamili x\n'],
#   '1 "'),
#  ([289,
#    'that exact u guy / girl miss sum 1 u could actual enjoy be-n . ... . #advicetewwhoevaneedsit . .\n'],
#   '. .'),
#  ([289, 'found part sing ! ! ! shoutout ? ( live\n'], '? ('),
#  ([290, "aahh , sorri love ... know you'll ace . )\n"], '. )'),
#  ([301, "dm'd get follow follow new twitter . shindig ? x\n"], '? x'),
#  ([312,
#    '( ) ; rt yes , yes . " chelsea , mean i\'m gonna valedictorian ? "\n'],
#   '? "'),
#  ([323,
#    '" avi > > > look like anim charact someth " thank big brother <3 luh yewww hoe !\n'],
#   '> > >'),
#  ([330, 'boy special enough first time . ahahahha . may te ) ) )\n'], ') ) )'),
#  ([332, 'thank , im sleep . kid ! ) game 5am ?\n'], '! )'),
#  ([340, 'yay ! ! #lifecomplet . tweet / facebook let know pleas\n'], '! ! #'),
#  ([344, '; rt taylor inspir trend topic world wide # 1\n'], '# 1'),
#  ([352,
#    'smirk norway killer breivik plead guilti ( reuter share friend : | | world news - top stori news , news feed n ...\n'],
#   ': | |'),
#  ([355,
#    '#1dnextalbumtitl : feel / rollercoast life . song cocept : life , #yolo , becom famous ? <3 14 #followmeplz ! <3 x15\n'],
#   '! <3'),
#  ([366, "better make wrong decis today , i'll upset #reallythough\n"], ", i'"),
#  ([372, "i'm week thanksss ! ? xxx\n"], '! ?'),
#  ([387, 'daili sentenc : " hate french teacher . " lmao <3\n'], ': "'),
#  ([390, 'zed ! msh aja ! ( rt lipbalm , salep kutu air ... ...\n'], '! ('),
#  ([405, '" put casper box ! " loov battl ! #crakkbitch\n'], '! "'),
#  ([416,
#    "morn . poor colton . wasn't fan would'v surviv win #idol phillip . ... shit . happi elis & holli surviv tho\n"],
#   '. ...'),
#  ([431, "coupl cover i'd never actual drawn octopus ... love\n"], "i'd"),
#  ([467, 'oh yeah still talk shxt ? ? ? hoe\n'], '? ? ?'),
#  ([492, 'love come outta freez classroom warm sun ( (\n'], '( ('),
#  ([501, 'love callin men " big poppa " phone ( ( (\n'], '( ( ('),
#  ([529,
#    'jersey shore 13x25 custom pictur frame / poster frame 2 " wide complet black wood frame (8 941 frame ...\n'],
#   '2 "'),
#  ([552, 'watch hehe ) )\n'], ') )'),
#  ([565, 'first twitcam ever watch boy . ( live\n'], '. ('),
#  ([622, '/ goofi self fuck w / tuff know wassup follow punk\n'], 'w /'),
#  ([650,
#    "haha ahww ) good ! i'm excit see ! know act like hang watermelon bust ? #whatupwiththat\n"],
#   "! i'm"),
#  ([726,
#    'make infant steeler jersey roethlisberg ? he babi daddi like alway hope , ...\n'],
#   ', ...'),
#  ([813,
#    "enough #howgoodcouldihavebeenif i'm start new hastag ... #howgreatimgonnabebecaus\n"],
#   '... #'),
#  ([846,
#    "ok , leto - i'v w / u 18yr ! i'v bought movi / cd / vyrt ass ! think i'v earn call ? u want blood ? !\n"],
#   "i'v"),
#  ([884, 'keep lay around ass ? !\n'], '? !'),
#  ([905, "happi 4.20 real . i'm spark name .\n"], ". i'm"),
#  ([929, '" " long day , bed . " night morn " morn sharon\n'], '. "'),
#  ([1049, 'friday payday & 4/20 ? ? hell yeah #reasons2dothebirdmanhandrub\n'],
#   '? ?'),
#  ([1102, 'feel better , feel bad , feel better , feel bad , work ... <\n'],
#   '... <'),
#  ([1185, "whatev time , i'm bother .\n"], ", i'm"),
#  ([1935, 'ah glad hear . must someth soon ! x\n'], '! x'),
#  ([2221,
#    'photo : chillin boy ! may know ? phinea ferm ) ( taken instagram )\n'],
#   ') ('),
#  ([4696, 'visit brother tmr bestest birthday gift eveerrr ! ! !\n'], '! ! !'),
#  ([6106, "got mid-term i'm impress ! ! #happi\n"], "i'm"),
#  ([6272,
#    'grate today dream fulfil ! ! heart full - first 3 complet track arriv back new york ! #yeslord !\n'],
#   '! !'),
#  ([33630, "thank sir > > don't trip lil mama ... keep doin ya thang !\n"],
#   '...')]
